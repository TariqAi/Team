# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv(r'C:\Users\ZMZM\Desktop\Dataset\optiver-trading-at-the-close\train.csv')

# %%
df.head(5)
# Out:
#    stock_id  date_id  seconds_in_bucket  imbalance_size  \
# 0         0        0                  0      3180602.69
# 1         1        0                  0       166603.91
# 2         2        0                  0       302879.87
# 3         3        0                  0     11917682.27
# 4         4        0                  0       447549.96
#
#    imbalance_buy_sell_flag  reference_price  matched_size  far_price  \
# 0                        1         0.999812   13380276.64        NaN
# 1                       -1         0.999896    1642214.25        NaN
# 2                       -1         0.999561    1819368.03        NaN
# 3                       -1         1.000171   18389745.62        NaN
# 4                       -1         0.999532   17860614.95        NaN
#
#    near_price  bid_price  bid_size  ask_price   ask_size  wap    target  \
# 0         NaN   0.999812  60651.50   1.000026    8493.03  1.0 -3.029704
# ...

# %%
df
# Out:
#          stock_id  date_id  seconds_in_bucket  imbalance_size  \
# 0               0        0                  0      3180602.69
# 1               1        0                  0       166603.91
# 2               2        0                  0       302879.87
# 3               3        0                  0     11917682.27
# 4               4        0                  0       447549.96
# ...           ...      ...                ...             ...
# 5237975       195      480                540      2440722.89
# 5237976       196      480                540       349510.47
# 5237977       197      480                540            0.00
# 5237978       198      480                540      1000898.84
# 5237979       199      480                540      1884285.71
#
#          imbalance_buy_sell_flag  reference_price  matched_size  far_price  \
# 0                              1         0.999812   13380276.64        NaN
# ...

# %%
df.shape
# Out:
# (5237980, 17)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5237980 entries, 0 to 5237979
# Data columns (total 17 columns):
#  #   Column                   Dtype
# ---  ------                   -----
#  0   stock_id                 int64
#  1   date_id                  int64
#  2   seconds_in_bucket        int64
#  3   imbalance_size           float64
#  4   imbalance_buy_sell_flag  int64
#  5   reference_price          float64
#  6   matched_size             float64
#  7   far_price                float64
#  8   near_price               float64
#  9   bid_price                float64
#  10  bid_size                 float64
#  11  ask_price                float64
#  12  ask_size                 float64
#  13  wap                      float64
#  14  target                   float64
#  15  time_id                  int64
#  16  row_id                   object
# dtypes: float64(11), int64(5), object(1)
# memory usage: 679.4+ MB

# %%
df.isnull().sum()
# Out:
# stock_id                         0
# date_id                          0
# seconds_in_bucket                0
# imbalance_size                 220
# imbalance_buy_sell_flag          0
# reference_price                220
# matched_size                   220
# far_price                  2894342
# near_price                 2857180
# bid_price                      220
# bid_size                         0
# ask_price                      220
# ask_size                         0
# wap                            220
# target                          88
# time_id                          0
# row_id                           0
# dtype: int64

# %%
df1 = df[df['wap'].isnull()]

# %%
df1.isnull().sum()
# Out:
# stock_id                     0
# date_id                      0
# seconds_in_bucket            0
# imbalance_size             220
# imbalance_buy_sell_flag      0
# reference_price            220
# matched_size               220
# far_price                  220
# near_price                 220
# bid_price                  220
# bid_size                     0
# ask_price                  220
# ask_size                     0
# wap                        220
# target                      88
# time_id                      0
# row_id                       0
# dtype: int64

# %%
df1
# Out:
#          stock_id  date_id  seconds_in_bucket  imbalance_size  \
# 369508        131       35                  0             NaN
# 369700        131       35                 10             NaN
# 369892        131       35                 20             NaN
# 370084        131       35                 30             NaN
# 370276        131       35                 40             NaN
# ...           ...      ...                ...             ...
# 4774999        19      438                500             NaN
# 4775199        19      438                510             NaN
# 4775399        19      438                520             NaN
# 4775599        19      438                530             NaN
# 4775799        19      438                540             NaN
#
#          imbalance_buy_sell_flag  reference_price  matched_size  far_price  \
# 369508                         0              NaN           NaN        NaN
# ...

# %%
df2 = df[df['date_id'] == 35]
df2.sample(20)
# Out:
#         stock_id  date_id  seconds_in_bucket  imbalance_size  \
# 377178       121       35                400    1.490661e+05
# 375630       109       35                320    4.729507e+05
# 370920         4       35                 80    2.325473e+07
# 370629        99       35                 60    6.020441e+05
# 374781        25       35                280    4.610580e+06
# 370748        24       35                 70    0.000000e+00
# 369873       112       35                 20    1.809419e+08
# 369802        38       35                 20    3.702375e+06
# 375425        95       35                310    2.717755e+06
# 371617       128       35                110    1.888014e+06
# 369690       121       35                 10    2.030865e+06
# 375231        93       35                300    3.077635e+05
# 369390        10       35                  0    6.973123e+05
# 378612        16       35                480    2.112772e+06
# ...

# %%
df3 = df[df['stock_id'] == 131]
df3.sample(20)
# Out:
#          stock_id  date_id  seconds_in_bucket  imbalance_size  \
# 522743        131       49                210            0.00
# 2848890       131      263                350      1528515.58
# 1668002       131      155                240      6459512.98
# 3190772       131      294                480      3115964.61
# 951371        131       89                160        17749.06
# 2841129       131      262                510            0.00
# 3476319       131      320                460      2329881.88
# 343012        131       32                270            0.00
# 4790711       131      440                180      1828003.66
# 2475964       131      229                310      4736662.34
# 2393777       131      222                 30      1821786.81
# 913276        131       85                420            0.00
# 868196        131       81                320     12297087.82
# 1586247       131      147                490       642563.99
# ...

# %%
df4 = df[df['stock_id']==131]
df4
# Out:
#          stock_id  date_id  seconds_in_bucket  imbalance_size  \
# 127           131        0                  0      1903085.22
# 318           131        0                 10      1849318.23
# 509           131        0                 20      1849318.23
# 700           131        0                 30      1849318.23
# 891           131        0                 40      1826510.36
# ...           ...      ...                ...             ...
# 5237111       131      480                500       332171.28
# 5237311       131      480                510       332171.28
# 5237511       131      480                520       366327.38
# 5237711       131      480                530       736814.00
# 5237911       131      480                540       734608.34
#
#          imbalance_buy_sell_flag  reference_price  matched_size  far_price  \
# 127                            1         0.999776    3585694.41        NaN
# ...

# %%
df5 = df4[df4['date_id'] == 35]
df5
# Out:
#         stock_id  date_id  seconds_in_bucket  imbalance_size  \
# 369508       131       35                  0             NaN
# 369700       131       35                 10             NaN
# 369892       131       35                 20             NaN
# 370084       131       35                 30             NaN
# 370276       131       35                 40             NaN
# 370468       131       35                 50             NaN
# 370660       131       35                 60             NaN
# 370852       131       35                 70             NaN
# 371044       131       35                 80             NaN
# 371236       131       35                 90             NaN
# 371428       131       35                100             NaN
# 371620       131       35                110             NaN
# 371812       131       35                120             NaN
# 372004       131       35                130             NaN
# ...

# %%
df5.shape
# Out:
# (55, 17)

# %%
df['seconds_in_bucket'].value_counts()
# Out:
# seconds_in_bucket
# 0      95236
# 410    95236
# 300    95236
# 310    95236
# 320    95236
# 330    95236
# 340    95236
# 350    95236
# 360    95236
# 370    95236
# 380    95236
# 390    95236
# 400    95236
# 420    95236
# 280    95236
# 430    95236
# 440    95236
# 450    95236
# 460    95236
# 470    95236
# 480    95236
# 490    95236
# 500    95236
# 510    95236
# 520    95236
# 530    95236
# 290    95236
# 270    95236
# 10     95236
# 130    95236
# 20     95236
# 30     95236
# 40     95236
# 50     95236
# 60     95236
# 70     95236
# 80     95236
# 90     95236
# 100    95236
# 110    95236
# 120    95236
# 140    95236
# 260    95236
# 150    95236
# 160    95236
# 170    95236
# 180    95236
# 190    95236
# 200    95236
# 210    95236
# 220    95236
# 230    95236
# 240    95236
# 250    95236
# 540    95236
# Name: count, dtype: int64

# %%
df
# Out:
#          stock_id  date_id  seconds_in_bucket  imbalance_size  \
# 0               0        0                  0      3180602.69
# 1               1        0                  0       166603.91
# 2               2        0                  0       302879.87
# 3               3        0                  0     11917682.27
# 4               4        0                  0       447549.96
# ...           ...      ...                ...             ...
# 5237975       195      480                540      2440722.89
# 5237976       196      480                540       349510.47
# 5237977       197      480                540            0.00
# 5237978       198      480                540      1000898.84
# 5237979       199      480                540      1884285.71
#
#          imbalance_buy_sell_flag  reference_price  matched_size  far_price  \
# 0                              1         0.999812   13380276.64        NaN
# ...

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
# Calculate correlation matrix
corr = df.corr()

# Create heatmap
plt.imshow(corr, cmap='coolwarm')

# %%
df.corr()
# Out:
#                              stock_id       date_id  seconds_in_bucket  \
# stock_id                 1.000000e+00  5.028770e-03      -1.116655e-16
# date_id                  5.028770e-03  1.000000e+00       1.280965e-14
# seconds_in_bucket       -1.116655e-16  1.280965e-14       1.000000e+00
# imbalance_size           2.463857e-02  6.441422e-03      -1.239456e-01
# imbalance_buy_sell_flag  4.066622e-03 -1.057243e-02      -3.634734e-03
# reference_price         -7.519350e-04 -6.456302e-03      -8.347507e-04
# matched_size             3.513044e-02  5.254090e-04       6.862495e-02
# far_price               -8.311000e-04 -3.004471e-03      -5.499413e-04
# near_price               4.736243e-03 -1.615006e-02       1.762744e-02
# bid_price                4.324366e-03 -6.528025e-03       1.481858e-02
# bid_size                 3.297499e-02  2.477643e-02       1.628673e-01
# ask_price               -6.341998e-03 -6.917286e-03      -1.782609e-02
# ...

# %%
correlation_matrix = df.corr()

# Create a correlation heatmap using seaborn
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=.5)
plt.title('Correlation Plot')
plt.show()

# %%
from scipy.stats import shapiro

# %%
# Normality
for i in df.columns :
    print("---"*30)
    print(i)
    print("%.4f-%.4f" %shapiro(df[i]))
# Out:
# ------------------------------------------------------------------------------------------
# stock_id
# C:\Users\ZMZM\anaconda3\Lib\site-packages\scipy\stats\_morestats.py:1882: UserWarning: p-value may not be accurate for N > 5000.
#   warnings.warn("p-value may not be accurate for N > 5000.")
# 0.9534-0.0000
# ------------------------------------------------------------------------------------------
# date_id
# 0.9522-0.0000
# ------------------------------------------------------------------------------------------
# seconds_in_bucket
# 0.9608-0.0000
# ------------------------------------------------------------------------------------------
# imbalance_size
# nan-1.0000
# ------------------------------------------------------------------------------------------
# imbalance_buy_sell_flag
# 0.7629-0.0000
# ------------------------------------------------------------------------------------------
# reference_price
# nan-1.0000
# ...

# %%
# Normality
for i in X.columns :
    print("---"*30)
    print(i)
    print("%.4f-%.4f" %shapiro(X[i]))

# %%
# v value

# %%
shapiro(df)

# %%
shapiro(X)

# %%
skewness_value = stats.skew(df)

# %%
import scipy.stats as stats

# %%
skewness_value

# %%
for column in df.columns:
    data = df[column]
    skewness_value = stats.skew(data)
    print(f'Column: {column}, Skewness: {skewness_value}')
    
    # 0.0 --> Perfect value
